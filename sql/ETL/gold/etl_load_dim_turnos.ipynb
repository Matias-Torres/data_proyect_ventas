# %%
# %sql
MERGE INTO catalog_ventas.gold.dim_turno AS tgt
USING (
  SELECT DISTINCT turno
  FROM catalog_ventas.silver.ventas_clean
  WHERE turno IS NOT NULL 
) AS src
ON tgt.turno = src.turno

WHEN NOT MATCHED THEN
  INSERT (turno)
  VALUES (src.turno);
