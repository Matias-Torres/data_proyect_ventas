# %%
# %sql
-- PASO 1: CREAR ESQUEMA SILVER
USE CATALOG catalog_ventas;

CREATE SCHEMA IF NOT EXISTS catalog_ventas.silver
COMMENT 'Esquema para datos limpios y de calidad (Silver Layer)';

SHOW SCHEMAS
