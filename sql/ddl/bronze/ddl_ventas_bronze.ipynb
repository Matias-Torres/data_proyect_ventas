# %%
# %sql
-- CREAR LA TABLA ventas_helados_bronze
DROP TABLE IF EXISTS catalog_ventas.raw.ventas_heladeria_bronze;

CREATE TABLE catalog_ventas.raw.ventas_heladeria_bronze (
  succodigo STRING,
  turno INT,
  caja INT,
  venta INT,
  comprobante STRING,
  vtaoperacion STRING,
  clinombre STRING,
  vtaestado STRING,
  vtafecha STRING,
  usulogin STRING,
  condvtapos STRING,
  delivery STRING,
  articulo INT,
  descrip STRING,
  precio STRING,
  cant INT,
  total STRING,
  sucursal INT,
  cliente INT,
  _rescued_data STRING,
  _ingestion_ts TIMESTAMP,
  _source_file STRING
)
USING DELTA

# %%
# %sql
-- VERIFICAR TABLA CREADA
--SHOW TABLES IN catalog_ventas.raw
