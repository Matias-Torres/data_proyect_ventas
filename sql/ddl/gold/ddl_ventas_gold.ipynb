# %%
# %sql
-- PASO 1: CREAR ESQUEMA GOLD
USE CATALOG catalog_ventas;

CREATE SCHEMA IF NOT EXISTS catalog_ventas.gold
COMMENT 'Esquema para datos agregados y analisis de negocio (Gold Layer)';

SHOW SCHEMAS
